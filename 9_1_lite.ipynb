# %% [markdown]
# Запустите, пожалуйста, раздел "Подготовка" и приступайте к выполнению заданий.

# %% [markdown]
# ## Подготовка

# %% [markdown]
# ### Импорт библиотек

# %%
# Массивы
import numpy as np

# Отрисовка графиков
import matplotlib.pyplot as plt

# Загрузка из google облака
import gdown

# Преобразование категориальных данных в one hot encoding
from tensorflow.keras.utils import to_categorical

# Работа с папками и файлами
import os

# Утилиты работы со временем
import time

# Работа со случайными числами
import random

# Математические функции
import math

# Сохранение и загрузка структур данных Python
import pickle

# Параметризация аудио
import librosa

# Оптимизаторы для обучения моделей
from tensorflow.keras.optimizers import Adam, RMSprop

# Конструирование и загрузка моделей нейронных сетей
from tensorflow.keras.models import Sequential, Model, load_model

# Основные слои
from tensorflow.keras.layers import concatenate, Input, Dense, Dropout, BatchNormalization, Flatten, Conv1D, Conv2D, LSTM

# Разбиение на обучающую и проверочную выборку
from sklearn.model_selection import train_test_split

# Кодирование категориальных меток, нормирование числовых данных
from sklearn.preprocessing import LabelEncoder, StandardScaler

# Матрица ошибок классификатора
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Отключение предупреждений
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# ### Загрузка датасета и подготовка данных

# %%
# Загрузка датасета из облака
gdown.download('https://storage.yandexcloud.net/aiueducation/Content/base/l12/genres.zip', None, quiet=False)

# Загрузка подготовленных данных
gdown.download('https://storage.yandexcloud.net/aiueducation/Content/base/l12/audio_data_mean.pickle', None, quiet=True)
# Out:
# Downloading...
# From: https://storage.yandexcloud.net/aiueducation/Content/base/l12/genres.zip
# To: /content/genres.zip
# 100%|██████████| 1.23G/1.23G [00:54<00:00, 22.3MB/s]
# 'audio_data_mean.pickle'

# %%
# Распаковка архива на локальный диск colab
# !unzip -qo genres.zip

# Проверка выгруженных папок
# !ls genres 

# Проверка содержимого одной папки
# !ls genres/blues
# Out:
# blues  classical  country  disco  hiphop  jazz	metal  pop  reggae  rock
# blues.00000.au	blues.00020.au	blues.00040.au	blues.00060.au	blues.00080.au
# blues.00001.au	blues.00021.au	blues.00041.au	blues.00061.au	blues.00081.au
# blues.00002.au	blues.00022.au	blues.00042.au	blues.00062.au	blues.00082.au
# blues.00003.au	blues.00023.au	blues.00043.au	blues.00063.au	blues.00083.au
# blues.00004.au	blues.00024.au	blues.00044.au	blues.00064.au	blues.00084.au
# blues.00005.au	blues.00025.au	blues.00045.au	blues.00065.au	blues.00085.au
# blues.00006.au	blues.00026.au	blues.00046.au	blues.00066.au	blues.00086.au
# blues.00007.au	blues.00027.au	blues.00047.au	blues.00067.au	blues.00087.au
# blues.00008.au	blues.00028.au	blues.00048.au	blues.00068.au	blues.00088.au
# blues.00009.au	blues.00029.au	blues.00049.au	blues.00069.au	blues.00089.au
# blues.00010.au	blues.00030.au	blues.00050.au	blues.00070.au	blues.00090.au
# blues.00011.au	blues.00031.au	blues.00051.au	blues.00071.au	blues.00091.au
# blues.00012.au	blues.00032.au	blues.00052.au	blues.00072.au	blues.00092.au
# blues.00013.au	blues.00033.au	blues.00053.au	blues.00073.au	blues.00093.au
# blues.00014.au	blues.00034.au	blues.00054.au	blues.00074.au	blues.00094.au
# blues.00015.au	blues.00035.au	blues.00055.au	blues.00075.au	blues.00095.au
# blues.00016.au	blues.00036.au	blues.00056.au	blues.00076.au	blues.00096.au
# blues.00017.au	blues.00037.au	blues.00057.au	blues.00077.au	blues.00097.au
# blues.00018.au	blues.00038.au	blues.00058.au	blues.00078.au	blues.00098.au
# blues.00019.au	blues.00039.au	blues.00059.au	blues.00079.au	blues.00099.au

# %%
# Установка констант

FILE_DIR = './genres'                     # Папка с файлами датасета
CLASS_LIST = os.listdir(FILE_DIR)         # Список классов, порядок меток не определен!
CLASS_LIST.sort()                         # Сортировка списка классов для фиксации порядка меток
CLASS_COUNT = len(CLASS_LIST)             # Количество классов
CLASS_FILES = 100                         # Общее количество файлов в каждом классе
FILE_INDEX_TRAIN_SPLIT = 90               # Количество файлов каждого класса на основной набор
VALIDATION_SPLIT = 0.1                    # Доля проверочной выборки в основном наборе
DURATION_SEC = 30                         # Анализируемая длительность аудиосигнала
N_FFT = 8192                              # Размер окна преобразования Фурье для расчета спектра
HOP_LENGTH = 512                          # Объем данных для расчета одного набора признаков

# %%
# Проверка списка классов
print(CLASS_LIST)
# Out:
# ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']

# %%
# Функция параметризации аудио

def get_features(y,                     # волновое представление сигнала
                 sr,                    # частота дискретизации сигнала y
                 n_fft=N_FFT,           # размер скользящего окна БПФ
                 hop_length=HOP_LENGTH  # шаг скользящего окна БПФ
                 ):
    # Вычисление различных параметров (признаков) аудио

    # Хромаграмма
    chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr, n_fft=n_fft, hop_length=hop_length)
    # Мел-кепстральные коэффициенты
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_fft=n_fft, hop_length=hop_length)
    # Среднеквадратическая амплитуда
    rmse = librosa.feature.rms(y=y, hop_length=hop_length)
    # Спектральный центроид
    spec_cent = librosa.feature.spectral_centroid(y=y, sr=sr, n_fft=n_fft, hop_length=hop_length)
    # Ширина полосы частот
    spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr, n_fft=n_fft, hop_length=hop_length)
    # Спектральный спад частоты
    rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr, n_fft=n_fft, hop_length=hop_length)
    # Пересечения нуля
    zcr = librosa.feature.zero_crossing_rate(y, hop_length=hop_length)
    
    # Сборка параметров в общий список:
    # На один файл один усредненный вектор признаков
    features = {'rmse': rmse.mean(axis=1, keepdims=True),
                'spct': spec_cent.mean(axis=1, keepdims=True),
                'spbw': spec_bw.mean(axis=1, keepdims=True),
                'roff': rolloff.mean(axis=1, keepdims=True),
                'zcr' : zcr.mean(axis=1, keepdims=True),
                'mfcc': mfcc.mean(axis=1, keepdims=True),
                'stft': chroma_stft.mean(axis=1, keepdims=True)}

    return features

# %%
# Функция объединения признаков в набор векторов

def stack_features(feat  # словарь признаков, отдельные векторы по ключу каждого признака
                   ):
    features = None
    for v in feat.values():
        features = np.vstack((features, v)) if features is not None else v

    return features.T

# %%
# Функция формирования набора признаков и метки класса для аудиофайла

def get_feature_list_from_file(class_index,  # индекс класса файла song_name
                               song_name,    # имя аудиофайла
                               duration_sec  # длительность аудио в секундах
                               ):
    # Загрузка в y первых duration_sec секунд аудиосигнала
    y, sr = librosa.load(song_name, mono=True, duration=duration_sec)

    # Извлечение параметров из аудиосигнала
    features = get_features(y, sr)
    feature_set = stack_features(features)

    # Перевод номера класса в one hot encoding
    y_label = to_categorical(class_index, CLASS_COUNT)

    return feature_set, y_label

# %%
# Функция формирования подвыборки признаков и меток класса для одного файла

def process_file(class_index,  # индекс класса аудиофайла
                 file_index,   # индекс (порядковый номер) аудиофайла в папке класса
                 duration_sec  # длительность аудио в секундах
                 ):
    x_list = []
    y_list = []
    class_name = CLASS_LIST[class_index]

    # Извлечение имени произведения
    song_name = f'{FILE_DIR}/{class_name}/{class_name}.{str(file_index).zfill(5)}.au'

    # Выборка признаков и метки класса для произведения
    feature_set, y_label = get_feature_list_from_file(class_index, 
                                                        song_name,
                                                        duration_sec)

    # Добавление данных в наборы
    for j in range(feature_set.shape[0]):
        x_list.append(feature_set[j])
        y_list.append(y_label)

    # Возврат имени файла и numpy-массивов призанков и меток класса
    return song_name, \
           np.array(x_list).astype('float32'), \
           np.array(y_list).astype('float32')

# %%
# Функция формирования набора данных из файлов всех классов по диапазону номеров файлов

def extract_data(file_index_start,          # начальный индекс аудиофайла
                 file_index_end,            # конечный индекс аудиофайла (не достигая)
                 duration_sec=DURATION_SEC  # длительность аудио в секундах
                 ):

    # Списки для последовательностей входных данных и меток класса
    x_data = None
    y_data = None

    # Фиксация времени старта формирования выборки
    curr_time = time.time()

    # Для всех классов:
    for class_index in range(len(CLASS_LIST)):
        # Для всех файлов текущего класса из заданного диапазона номеров:
        for file_index in range(file_index_start, file_index_end):
            # Обработка одного файла и добавление данных к общим массивам
            _, file_x_data, file_y_data = process_file(class_index, file_index, duration_sec)
            x_data = file_x_data if x_data is None else np.vstack([x_data, file_x_data])
            y_data = file_y_data if y_data is None else np.vstack([y_data, file_y_data])

        # Вывод информации о готовности обработки датасета
        print(f'Жанр {CLASS_LIST[class_index]} готов -> {round(time.time() - curr_time)} c')
        curr_time = time.time()

    # Возврат массивов набора данных
    return x_data, y_data

# %%
# Восстановление датасета аудио
# Данные привязаны к порядку следования меток классов!
# Порядок классов фиксирован сортировкой списка меток классов

with open('/content/audio_data_mean.pickle', 'rb') as f:
    x_train_data, y_train_data = pickle.load(f)

# %%
# Нормирование признаков в соответствии со стандартным нормальным распределением

x_scaler = StandardScaler()
x_train_data_scaled = x_scaler.fit_transform(x_train_data)

# %%
# Разделение набора данных на обучающую и проверочную выборки
# Параметр stratify указывает метки классов, по которым происходит балансировка разделения

x_train, x_val, y_train, y_val = train_test_split(x_train_data_scaled,
                                                  y_train_data,
                                                  stratify=y_train_data,
                                                  test_size=VALIDATION_SPLIT)

# %% [markdown]
# ### Функция вывода графиков точности и ошибки по эпохам обучения

# %%
# Вывод графиков точности и ошибки распознавания на обучающей и проверочной выборках

def show_history(history  # объект-результат метода обучения .fit()
                 ):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 5))
    fig.suptitle('График процесса обучения модели')
    ax1.plot(history.history['accuracy'], 
               label='Доля верных ответов на обучающем наборе')
    ax1.plot(history.history['val_accuracy'], 
               label='Доля верных ответов на проверочном наборе')
    ax1.xaxis.get_major_locator().set_params(integer=True)
    ax1.set_xlabel('Эпоха обучения')
    ax1.set_ylabel('Доля верных ответов')
    ax1.legend()

    ax2.plot(history.history['loss'], 
               label='Ошибка на обучающем наборе')
    ax2.plot(history.history['val_loss'], 
               label='Ошибка на проверочном наборе')
    ax2.xaxis.get_major_locator().set_params(integer=True)
    ax2.set_xlabel('Эпоха обучения')
    ax2.set_ylabel('Ошибка')
    ax2.legend()
    plt.show()

# %% [markdown]
# ### Функции визуализации распознавания отдельных звуковых файлов

# %%
# Классификация файла и визуализация предсказания модели для него

def classify_file(model,        # обученная модель классификатора
                  x_scaler,     # настроенный нормировщих входных данных
                  class_index,  # верный индекс класса аудиофайла
                  file_index    # индекс (порядковый номер) аудиофайла в папке
                  ):
    # Подготовка выборки данных файла произведения
    song_name, file_x_data, file_y_data = process_file(class_index, file_index, DURATION_SEC)

    # Нормирование признаков уже настроенным нормировщиком
    file_x_data = x_scaler.transform(file_x_data)

    print('Файл:', song_name)
    print('Векторы для предсказания:', file_x_data.shape)

    # Вычисление предсказания по выборке
    predict = model.predict(file_x_data)
    # Определение среднего предсказания (голосование)
    predict_mean = predict.mean(axis=0)
    # Определение индекса класса по результату голосования
    predict_class_index = np.argmax(predict_mean)
    # Вычисление признака правильного предсказания
    predict_good = predict_class_index == class_index

    # Визуализация предсказания сети для файла
    plt.figure(figsize=(10,3))
    print('Классификация сети:', CLASS_LIST[predict_class_index], '-', 'ВЕРНО :-)' if predict_good else 'НЕВЕРНО.')
    plt.title('Среднее распределение векторов предсказаний')
    plt.bar(CLASS_LIST, predict_mean, color='g' if predict_good else 'r')
    plt.show()
    print('---------------------------------------------------------------')

    # Возврат результата предсказания
    return predict_class_index

# %%
# Классификация и визуализация нескольких файлов каждого класса 

def classify_test_files(model,       # обученная модель классификатора
                        x_scaler,    # настроенный нормировщих входных данных
                        from_index,  # индекс аудиофайла, с которого начинать визуализацию
                        n_files):    # количество файлов для визуализации
    predict_all = 0
    predict_good = 0
    y_true = []
    y_pred = []

    # Классификация каждого файла и аккумуляция результатов классификации
    for class_index in range(CLASS_COUNT):
        for file_index in range(from_index, from_index + n_files):
            predict_class_index = classify_file(model, x_scaler, class_index, file_index)
            y_true.append(class_index)
            y_pred.append(predict_class_index)
            predict_all += 1
            predict_good += (predict_class_index == class_index)

    # Расчет и вывод итогов классификации
    good_ratio = round(predict_good / predict_all * 100., 2)
    print(f'=== Обработано образцов: {predict_all}, из них распознано верно: {predict_good}, доля верных: {good_ratio}% ===')   

    # Построение матрицы ошибок без нормализации, покажет попадания в штуках
    cm = confusion_matrix(y_true, y_pred)

    # Отрисовка матрицы ошибок
    fig, ax = plt.subplots(figsize=(10, 10))
    ax.set_title('Матрица ошибок по файлам аудио (не нормализованная)')
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=CLASS_LIST)
    disp.plot(ax=ax)
    plt.show()

# %% [markdown]
# ##Заданиe

# %% [markdown]
# В предыдущих ячейках были подготовлены все данные для обучения модели нейронной сети.
# 1. Проверьте форму данных обучающей и проверочной выборок (выведите на экран).

# %%
# Ваше решение

# %%
print(x_train.shape, y_train.shape, x_val.shape, y_val.shape)
# Out:
# (810, 37) (810, 10) (90, 37) (90, 10)

# %% [markdown]
# 2. Составьте модель классификатора на полносвязных слоях и сохраните ее в переменной **model**. Для этого:
#  - Используйте заготовку для последовательной модели **Sequential**;
#  - Добавьте полносвязный слой на **64** нейрона с активационной функцией **'relu'**, после него добавьте слой **Dropout** с долей отключаемых нейронов **30%**;
#  - Добавьте следующий полносвязный слой на **32** нейрона с активационной функцией **'relu'**, после него добавьте слой **Dropout** с долей отключаемых нейронов **30%**;
#  - Добавьте следующий полносвязный слой на **16** нейронов с активационной функцией **'relu'**, после него добавьте слой **Dropout** с долей отключаемых нейронов **20%**;
#  - Добавьте слой пакетной нормализации;
#  - Добавьте финальный полносвязный слой классификатора на число нейронов по числу классов (**CLASS_COUNT**) с активационной функцией **'softmax'** .

# %%
# Ваше решение

# %%
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=x_train.shape[1:]))
model.add(Dropout(0.3))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(16, activation='relu'))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(Dense(CLASS_COUNT, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                2432
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dropout_2 (Dropout)         (None, 16)                0
#
#  batch_normalization (BatchN  (None, 16)               64
#  ormalization)
#
#  dense_3 (Dense)             (None, 10)                170
#
# =================================================================
# Total params: 5,274
# Trainable params: 5,242
# Non-trainable params: 32
# _________________________________________________________________

# %%
# Используем для работы с категориальными данными
from tensorflow.keras import utils

# %%
utils.plot_model(model, dpi=60)

# %% [markdown]
# 3. Откомпилируйте созданную модель методом `.compile()` с указанием оптимизатора **Adam** и начальным шагом обучения **0.0001**, функцией ошибки **'categorical_crossentropy'** и метрикой **'accuracy'**;
# Выведите на экран сводку архитектуры полученной модели методом `.summary()` .

# %%
model.compile(optimizer=Adam(learning_rate=1e-4),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                2432
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dropout_2 (Dropout)         (None, 16)                0
#
#  batch_normalization (BatchN  (None, 16)               64
#  ormalization)
#
#  dense_3 (Dense)             (None, 10)                170
#
# =================================================================
# Total params: 5,274
# Trainable params: 5,242
# Non-trainable params: 32
# _________________________________________________________________

# %%
# Ваше решение

# %% [markdown]
# 4. Обучите модель и выведите графики обучения:
#  - Обучите созданную и откомпилированную модель классификатора на данных обучающей выборки **x_train, y_train**, используя проверочные данные **x_val, y_val**, размер батча **32** и количество эпох **1000**. Результаты обучения сохраните в переменной **history** .
#  - В разделе **"Функция вывода графиков точности и ошибки по эпохам обучения"** найдите определение функции `show_history()`, изучите требуемые параметры для нее и используйте для построения графиков точности и ошибки на протяжении эпох обучения.

# %%
# Ваше решение

# %%
history = model.fit(x_train,
                    y_train,
                    epochs=1000,
                    batch_size=32,
                    validation_data=(x_val, y_val))

show_history(history)
# Out:
# Epoch 1/1000
# 26/26 [==============================] - 3s 11ms/step - loss: 2.7004 - accuracy: 0.1247 - val_loss: 2.2323 - val_accuracy: 0.1333
# Epoch 2/1000
# 26/26 [==============================] - 0s 4ms/step - loss: 2.6209 - accuracy: 0.1593 - val_loss: 2.1999 - val_accuracy: 0.1778
# Epoch 3/1000
# 26/26 [==============================] - 0s 4ms/step - loss: 2.6070 - accuracy: 0.1519 - val_loss: 2.1696 - val_accuracy: 0.2667
# Epoch 4/1000
# 26/26 [==============================] - 0s 4ms/step - loss: 2.5669 - accuracy: 0.1556 - val_loss: 2.1409 - val_accuracy: 0.2444
# Epoch 5/1000
# 26/26 [==============================] - 0s 4ms/step - loss: 2.4763 - accuracy: 0.1642 - val_loss: 2.1109 - val_accuracy: 0.2778
# Epoch 6/1000
# 26/26 [==============================] - 0s 4ms/step - loss: 2.5290 - accuracy: 0.1494 - val_loss: 2.0837 - val_accuracy: 0.2889
# Epoch 7/1000
# 26/26 [==============================] - 0s 4ms/step - loss: 2.5321 - accuracy: 0.1494 - val_loss: 2.0591 - val_accuracy: 0.2889
# Epoch 8/1000
# 26/26 [==============================] - 0s 4ms/step - loss: 2.4696 - accuracy: 0.1580 - val_loss: 2.0331 - val_accuracy: 0.3000
# Epoch 9/1000
# 26/26 [==============================] - 0s 4ms/step - loss: 2.5088 - accuracy: 0.1667 - val_loss: 2.0082 - val_accuracy: 0.3000
# Epoch 10/1000
# 26/26 [==============================] - 0s 4ms/step - loss: 2.4510 - accuracy: 0.1778 - val_loss: 1.9900 - val_accuracy: 0.3000
# Epoch 11/1000
# 26/26 [==============================] - 0s 4ms/step - loss: 2.4104 - accuracy: 0.1765 - val_loss: 1.9744 - val_accuracy: 0.3111
# Epoch 12/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 2.3741 - accuracy: 0.1926 - val_loss: 1.9621 - val_accuracy: 0.3222
# Epoch 13/1000
# 26/26 [==============================] - 0s 4ms/step - loss: 2.
1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9598 - accuracy: 0.6753 - val_loss: 1.0597 - val_accuracy: 0.5889
# Epoch 893/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9604 - accuracy: 0.6568 - val_loss: 1.0539 - val_accuracy: 0.5889
# Epoch 894/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9992 - accuracy: 0.6531 - val_loss: 1.0568 - val_accuracy: 0.6000
# Epoch 895/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9636 - accuracy: 0.6654 - val_loss: 1.0607 - val_accuracy: 0.6000
# Epoch 896/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9697 - accuracy: 0.6802 - val_loss: 1.0604 - val_accuracy: 0.6111
# Epoch 897/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9099 - accuracy: 0.6963 - val_loss: 1.0592 - val_accuracy: 0.6000
# Epoch 898/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9684 - accuracy: 0.6568 - val_loss: 1.0554 - val_accuracy: 0.6000
# Epoch 899/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 1.0437 - accuracy: 0.6444 - val_loss: 1.0556 - val_accuracy: 0.6111
# Epoch 900/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9966 - accuracy: 0.6506 - val_loss: 1.0600 - val_accuracy: 0.6111
# Epoch 901/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9353 - accuracy: 0.6765 - val_loss: 1.0589 - val_accuracy: 0.6111
# Epoch 902/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9733 - accuracy: 0.6580 - val_loss: 1.0566 - val_accuracy: 0.6111
# Epoch 903/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 1.0049 - accuracy: 0.6642 - val_loss: 1.0557 - val_accuracy: 0.6000
# Epoch 904/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9234 - accuracy: 0.6753 - val_loss: 1.0545 - val_accuracy: 0.6000
# Epoch 905/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9466 - accuracy: 0.6778 - val_loss: 1.0539 - val_accuracy: 0.5889
# Epoch 906/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9476 - accuracy: 0.6741 - val_loss: 1.0570 - val_accuracy: 0.5889
# Epoch 907/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9187 - accuracy: 0.6741 - val_loss: 1.0540 - val_accuracy: 0.5889
# Epoch 908/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9376 - accuracy: 0.6728 - val_loss: 1.0529 - val_accuracy: 0.5889
# Epoch 909/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.8982 - accuracy: 0.6840 - val_loss: 1.0525 - val_accuracy: 0.5889
# Epoch 910/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9642 - accuracy: 0.6815 - val_loss: 1.0572 - val_accuracy: 0.5889
# Epoch 911/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9504 - accuracy: 0.6815 - val_loss: 1.0548 - val_accuracy: 0.5889
# Epoch 912/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9606 - accuracy: 0.6519 - val_loss: 1.0543 - val_accuracy: 0.5889
# Epoch 913/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9371 - accuracy: 0.6790 - val_loss: 1.0549 - val_accuracy: 0.6000
# Epoch 914/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9638 - accuracy: 0.6802 - val_loss: 1.0548 - val_accuracy: 0.6111
# Epoch 915/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9453 - accuracy: 0.6543 - val_loss: 1.0569 - val_accuracy: 0.6000
# Epoch 916/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9544 - accuracy: 0.6827 - val_loss: 1.0605 - val_accuracy: 0.6111
# Epoch 917/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9782 - accuracy: 0.6519 - val_loss: 1.0636 - val_accuracy: 0.6111
# Epoch 918/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9129 - accuracy: 0.6704 - val_loss: 1.0628 - val_accuracy: 0.6000
# Epoch 919/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9471 - accuracy: 0.6630 - val_loss: 1.0670 - val_accuracy: 0.6000
# Epoch 920/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9755 - accuracy: 0.6519 - val_loss: 1.0646 - val_accuracy: 0.6000
# Epoch 921/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9215 - accuracy: 0.6975 - val_loss: 1.0628 - val_accuracy: 0.6000
# Epoch 922/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9599 - accuracy: 0.6630 - val_loss: 1.0652 - val_accuracy: 0.6000
# Epoch 923/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9452 - accuracy: 0.6864 - val_loss: 1.0605 - val_accuracy: 0.6000
# Epoch 924/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9123 - accuracy: 0.6901 - val_loss: 1.0628 - val_accuracy: 0.5889
# Epoch 925/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9573 - accuracy: 0.6778 - val_loss: 1.0618 - val_accuracy: 0.5889
# Epoch 926/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9832 - accuracy: 0.6506 - val_loss: 1.0639 - val_accuracy: 0.5889
# Epoch 927/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9861 - accuracy: 0.6691 - val_loss: 1.0623 - val_accuracy: 0.5889
# Epoch 928/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9590 - accuracy: 0.6481 - val_loss: 1.0638 - val_accuracy: 0.5889
# Epoch 929/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9383 - accuracy: 0.6667 - val_loss: 1.0627 - val_accuracy: 0.5889
# Epoch 930/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9162 - accuracy: 0.6877 - val_loss: 1.0633 - val_accuracy: 0.5889
# Epoch 931/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9611 - accuracy: 0.6617 - val_loss: 1.0614 - val_accuracy: 0.6000
# Epoch 932/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9679 - accuracy: 0.6679 - val_loss: 1.0552 - val_accuracy: 0.6000
# Epoch 933/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9405 - accuracy: 0.6926 - val_loss: 1.0538 - val_accuracy: 0.6000
# Epoch 934/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9575 - accuracy: 0.6704 - val_loss: 1.0585 - val_accuracy: 0.6000
# Epoch 935/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9641 - accuracy: 0.6556 - val_loss: 1.0629 - val_accuracy: 0.5889
# Epoch 936/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9749 - accuracy: 0.6630 - val_loss: 1.0548 - val_accuracy: 0.6111
# Epoch 937/1000
# 26/26 [==============================] - 0s 7ms/step - loss: 0.9281 - accuracy: 0.6765 - val_loss: 1.0515 - val_accuracy: 0.6111
# Epoch 938/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9827 - accuracy: 0.6481 - val_loss: 1.0510 - val_accuracy: 0.6000
# Epoch 939/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9257 - accuracy: 0.6765 - val_loss: 1.0541 - val_accuracy: 0.5889
# Epoch 940/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9870 - accuracy: 0.6642 - val_loss: 1.0513 - val_accuracy: 0.5889
# Epoch 941/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9325 - accuracy: 0.6975 - val_loss: 1.0519 - val_accuracy: 0.5889
# Epoch 942/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9521 - accuracy: 0.6642 - val_loss: 1.0500 - val_accuracy: 0.5889
# Epoch 943/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9038 - accuracy: 0.6938 - val_loss: 1.0477 - val_accuracy: 0.6000
# Epoch 944/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9093 - accuracy: 0.6765 - val_loss: 1.0509 - val_accuracy: 0.6000
# Epoch 945/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9429 - accuracy: 0.6605 - val_loss: 1.0491 - val_accuracy: 0.5889
# Epoch 946/1000
# 26/26 [==============================] - 0s 7ms/step - loss: 0.9469 - accuracy: 0.6667 - val_loss: 1.0471 - val_accuracy: 0.5889
# Epoch 947/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9129 - accuracy: 0.6864 - val_loss: 1.0463 - val_accuracy: 0.6000
# Epoch 948/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9131 - accuracy: 0.6827 - val_loss: 1.0504 - val_accuracy: 0.6111
# Epoch 949/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.8985 - accuracy: 0.7037 - val_loss: 1.0530 - val_accuracy: 0.5889
# Epoch 950/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9552 - accuracy: 0.6827 - val_loss: 1.0521 - val_accuracy: 0.6111
# Epoch 951/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9565 - accuracy: 0.6753 - val_loss: 1.0544 - val_accuracy: 0.6111
# Epoch 952/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9566 - accuracy: 0.6790 - val_loss: 1.0548 - val_accuracy: 0.5889
# Epoch 953/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9720 - accuracy: 0.6519 - val_loss: 1.0565 - val_accuracy: 0.5889
# Epoch 954/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9536 - accuracy: 0.6654 - val_loss: 1.0657 - val_accuracy: 0.5889
# Epoch 955/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0111 - accuracy: 0.6432 - val_loss: 1.0629 - val_accuracy: 0.5889
# Epoch 956/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9362 - accuracy: 0.6864 - val_loss: 1.0584 - val_accuracy: 0.5889
# Epoch 957/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.8835 - accuracy: 0.7062 - val_loss: 1.0556 - val_accuracy: 0.6000
# Epoch 958/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9209 - accuracy: 0.6852 - val_loss: 1.0571 - val_accuracy: 0.6000
# Epoch 959/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9573 - accuracy: 0.6617 - val_loss: 1.0562 - val_accuracy: 0.6000
# Epoch 960/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9466 - accuracy: 0.6667 - val_loss: 1.0536 - val_accuracy: 0.6111
# Epoch 961/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9394 - accuracy: 0.6494 - val_loss: 1.0554 - val_accuracy: 0.6111
# Epoch 962/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9562 - accuracy: 0.6815 - val_loss: 1.0567 - val_accuracy: 0.6111
# Epoch 963/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9735 - accuracy: 0.6617 - val_loss: 1.0565 - val_accuracy: 0.6111
# Epoch 964/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9169 - accuracy: 0.6889 - val_loss: 1.0555 - val_accuracy: 0.6000
# Epoch 965/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9850 - accuracy: 0.6444 - val_loss: 1.0557 - val_accuracy: 0.6000
# Epoch 966/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9782 - accuracy: 0.6593 - val_loss: 1.0579 - val_accuracy: 0.6000
# Epoch 967/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9799 - accuracy: 0.6704 - val_loss: 1.0646 - val_accuracy: 0.6000
# Epoch 968/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9265 - accuracy: 0.6728 - val_loss: 1.0634 - val_accuracy: 0.6000
# Epoch 969/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9467 - accuracy: 0.6728 - val_loss: 1.0657 - val_accuracy: 0.6000
# Epoch 970/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9301 - accuracy: 0.6778 - val_loss: 1.0664 - val_accuracy: 0.6000
# Epoch 971/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9675 - accuracy: 0.6926 - val_loss: 1.0658 - val_accuracy: 0.6000
# Epoch 972/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9484 - accuracy: 0.6815 - val_loss: 1.0667 - val_accuracy: 0.5889
# Epoch 973/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9111 - accuracy: 0.6963 - val_loss: 1.0663 - val_accuracy: 0.5889
# Epoch 974/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9692 - accuracy: 0.6741 - val_loss: 1.0604 - val_accuracy: 0.5889
# Epoch 975/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9447 - accuracy: 0.6679 - val_loss: 1.0589 - val_accuracy: 0.5889
# Epoch 976/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9364 - accuracy: 0.6790 - val_loss: 1.0564 - val_accuracy: 0.6000
# Epoch 977/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9204 - accuracy: 0.7012 - val_loss: 1.0555 - val_accuracy: 0.6000
# Epoch 978/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9397 - accuracy: 0.6753 - val_loss: 1.0581 - val_accuracy: 0.6000
# Epoch 979/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9406 - accuracy: 0.6580 - val_loss: 1.0576 - val_accuracy: 0.6000
# Epoch 980/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.8679 - accuracy: 0.7025 - val_loss: 1.0555 - val_accuracy: 0.6000
# Epoch 981/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9492 - accuracy: 0.6975 - val_loss: 1.0529 - val_accuracy: 0.6000
# Epoch 982/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9178 - accuracy: 0.6889 - val_loss: 1.0510 - val_accuracy: 0.5667
# Epoch 983/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9671 - accuracy: 0.6704 - val_loss: 1.0505 - val_accuracy: 0.5667
# Epoch 984/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.8982 - accuracy: 0.6951 - val_loss: 1.0551 - val_accuracy: 0.5778
# Epoch 985/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9237 - accuracy: 0.6889 - val_loss: 1.0605 - val_accuracy: 0.5667
# Epoch 986/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9554 - accuracy: 0.6728 - val_loss: 1.0627 - val_accuracy: 0.5667
# Epoch 987/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9433 - accuracy: 0.6802 - val_loss: 1.0638 - val_accuracy: 0.5667
# Epoch 988/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9519 - accuracy: 0.6741 - val_loss: 1.0666 - val_accuracy: 0.5667
# Epoch 989/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.8432 - accuracy: 0.7259 - val_loss: 1.0654 - val_accuracy: 0.5667
# Epoch 990/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9346 - accuracy: 0.6765 - val_loss: 1.0675 - val_accuracy: 0.5667
# Epoch 991/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9199 - accuracy: 0.6877 - val_loss: 1.0663 - val_accuracy: 0.5889
# Epoch 992/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9125 - accuracy: 0.6889 - val_loss: 1.0686 - val_accuracy: 0.5889
# Epoch 993/1000
# 26/26 [==============================] - 0s 5ms/step - loss: 0.9625 - accuracy: 0.6753 - val_loss: 1.0693 - val_accuracy: 0.6000
# Epoch 994/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9367 - accuracy: 0.6815 - val_loss: 1.0670 - val_accuracy: 0.6000
# Epoch 995/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9436 - accuracy: 0.6778 - val_loss: 1.0662 - val_accuracy: 0.6111
# Epoch 996/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.8641 - accuracy: 0.7136 - val_loss: 1.0685 - val_accuracy: 0.6111
# Epoch 997/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.8464 - accuracy: 0.7198 - val_loss: 1.0625 - val_accuracy: 0.6000
# Epoch 998/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.8729 - accuracy: 0.7123 - val_loss: 1.0656 - val_accuracy: 0.6000
# Epoch 999/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.8571 - accuracy: 0.7086 - val_loss: 1.0684 - val_accuracy: 0.6000
# Epoch 1000/1000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.9028 - accuracy: 0.6889 - val_loss: 1.0655 - val_accuracy: 0.6000

# %% [markdown]
# 5. Проверьте работу модели:
#  - В разделе **Функции визуализации распознавания отдельных звуковых файлов** найдите определение функции `classify_test_files()` и изучите ее параметры. Используйте функцию для визуализации работы классификатора на произвольном количестве тестовых звуковых файлов, полагая, что:
#  - вы используете обученная в задании 4 модель классификатора аудио;
#  - нормализатор **x_scaler** уже настроен ранее в ноутбуке, и его нужно передать в функцию `classify_test_files()` вместо параметра **x_scaler**;
#  - тестовые звуковые файлы начинаются с индекса **90** и всего их ровно **10** для каждого класса.

# %%
# Ваше решение

# %%
classify_test_files(model, x_scaler, 93, 4)
# Out:
# Файл: ./genres/blues/blues.00093.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 87ms/step
# Классификация сети: disco - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/blues/blues.00094.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 14ms/step
# Классификация сети: disco - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/blues/blues.00095.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 15ms/step
# Классификация сети: disco - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/blues/blues.00096.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 14ms/step
# Классификация сети: hiphop - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/classical/classical.00093.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 15ms/step
# Классификация сети: rock - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/classical/classical.00094.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 16ms/step
# Классификация сети: rock - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/classical/classical.00095.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 15ms/step
# Классификация сети: rock - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/classical/classical.00096.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 17ms/step
# Классификация сети: rock - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/country/country.00093.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 16ms/step
# Классификация сети: hiphop - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/country/country.00094.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 14ms/step
# Классификация сети: disco - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/country/country.00095.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 14ms/step
# Классификация сети: disco - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/country/country.00096.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 14ms/step
# Классификация сети: country - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/disco/disco.00093.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 14ms/step
# Классификация сети: reggae - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/disco/disco.00094.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 19ms/step
# Классификация сети: hiphop - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/disco/disco.00095.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 14ms/step
# Классификация сети: blues - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/disco/disco.00096.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 14ms/step
# Классификация сети: disco - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/hiphop/hiphop.00093.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 14ms/step
# Классификация сети: blues - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/hiphop/hiphop.00094.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 14ms/step
# Классификация сети: metal - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/hiphop/hiphop.00095.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 16ms/step
# Классификация сети: blues - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/hiphop/hiphop.00096.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 14ms/step
# Классификация сети: jazz - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/jazz/jazz.00093.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 14ms/step
# Классификация сети: pop - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/jazz/jazz.00094.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 14ms/step
# Классификация сети: pop - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/jazz/jazz.00095.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 17ms/step
# Классификация сети: pop - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/jazz/jazz.00096.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 29ms/step
# Классификация сети: pop - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/metal/metal.00093.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 16ms/step
# Классификация сети: blues - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/metal/metal.00094.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 14ms/step
# Классификация сети: blues - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/metal/metal.00095.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 14ms/step
# Классификация сети: blues - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/metal/metal.00096.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 14ms/step
# Классификация сети: blues - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/pop/pop.00093.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 15ms/step
# Классификация сети: classical - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/pop/pop.00094.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 14ms/step
# Классификация сети: classical - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/pop/pop.00095.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 14ms/step
# Классификация сети: classical - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/pop/pop.00096.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 14ms/step
# Классификация сети: classical - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/reggae/reggae.00093.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 14ms/step
# Классификация сети: classical - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/reggae/reggae.00094.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 14ms/step
# Классификация сети: rock - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/reggae/reggae.00095.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 14ms/step
# Классификация сети: jazz - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/reggae/reggae.00096.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 14ms/step
# Классификация сети: metal - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/rock/rock.00093.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 18ms/step
# Классификация сети: hiphop - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/rock/rock.00094.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 15ms/step
# Классификация сети: country - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/rock/rock.00095.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 14ms/step
# Классификация сети: country - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/rock/rock.00096.au
# Векторы для предсказания: (1, 37)
# 1/1 [==============================] - 0s 15ms/step
# Классификация сети: country - НЕВЕРНО.
# ---------------------------------------------------------------
# === Обработано образцов: 40, из них распознано верно: 2, доля верных: 5.0% ===
